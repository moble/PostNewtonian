# %% [markdown]
# To do:
#  * Expand in power series for $v$ and drop above certain order
#  * Eliminate $(0)$ arguments
#  * Generate and output sympy code
#  * Generate and output C++ code
#  * Loop over $m$ values
#  * Loop over components
#  * Check each expression (as feasible) to ensure that the latex-ripping works properly
#  * Check that my reductions are appropriate

# %% [markdown]
# We have a couple formulas at lowest order that can guide us in our choice of terms to keep:
#
# $dv/dt = -\mathcal{L}/(dE/dv) \approx -(2v^{10}/5)/(-v/8) = v^9/20$
#
# $d^2v/dt^2 = 9v^8/20\, dv/dt = 9 v^{17}/400$
#
# \begin{align*}
# \hat{n} \cdot \vec{v} &\approx v\, \frac{dr}{dt} \\
# &= v\, \frac{d(1/v^2)}{dt} \\
# &= -\frac{2}{v^2}\, \frac{dv}{dt} \\
# &= -\frac{v^7}{10}
# \end{align*}

# %% [markdown]
# Clearing the cache is not strictly necessary, but I have found the cache can sometimes cause trouble.

# %%
from sympy.core.cache import clear_cache
clear_cache()

# %%
from __future__ import division, print_function
import sympy
from sympy import *
from sympy import Rational as frac
import re
import simpletensors
from simpletensors import Vector, xHat, yHat, zHat
from simpletensors import TensorProduct, SymmetricTensorProduct, Tensor, ReduceExpr
import sphericalharmonictensors
init_printing()


var('mu,ell,A,B,C,epsilon')
var('jk,jkl,jklm,jklmn,jklmno,jklmnop,jklmnopq') # Index sets Blanchet uses
var('i,j,k,l,m,n,o') # Indices Bohé et al. use
#var('Subscript', cls=Function); # Mathematica will return this, so let's just pretend it exists
var('vartheta, varphi')
var('nu, m, delta, c, t, v0')

# These are related scalar functions of time
var('v, gamma, r', cls=Function)
v = v(t)
x = v**2
Omega = v**3
# gamma = v**2*(1 + (1-nu/3)*v**2 + (1-65*nu/12)*v**4) # APPROXIMATELY!!!  Change this later
# dvdt = 
#r = 1/gamma
gamma = gamma(t)
r = r(t)
r = 1/v**2 # APPROXIMATELY!!!  Just for testing.  Change this later

# These get redefined momentarily, but have to exist first
var('nHat, lambdaHat, ellHat', cls=Function)
# And now we define them as vector functions of time
nHat = Vector('nHat', r'\hat{n}', [cos(Omega*t),sin(Omega*t),0,])(t)
lambdaHat = Vector('lambdaHat', r'\hat{\lambda}', [-sin(Omega*t),cos(Omega*t),0,])(t)
ellHat = Vector('ellHat', r'\hat{\ell}', [0,0,1,])(t)

# # These are the spin functions -- first, the individual components as regular sympy.Function objects; then the vectors themselves
# var('S_n, S_lambda, S_ell', cls=Function)
# var('Sigma_n, Sigma_lambda, Sigma_ell', cls=Function)
# SigmaVec = Vector('SigmaVec', r'\vec{\Sigma}', [Sigma_n(t), Sigma_lambda(t), Sigma_ell(t)])(t)
# SVec = Vector('S', r'\vec{S}', [S_n(t), S_lambda(t), S_ell(t)])(t)

# These are the spin functions -- first, the individual components as regular sympy.Function objects; then the vectors themselves
var('S_n, S_lambda, S_ell')
var('Sigma_n, Sigma_lambda, Sigma_ell')
SigmaVec = Vector('SigmaVec', r'\vec{\Sigma}', [Sigma_n, Sigma_lambda, Sigma_ell])(t)
SVec = Vector('S', r'\vec{S}', [S_n, S_lambda, S_ell])(t)

# %%
SimplifyVectorDerivatives = {diff(nHat,t):Omega*lambdaHat, diff(lambdaHat,t):-Omega*nHat}
DropvDerivatives = {(diff(v,t,vDerivs).subs(t,0))**vDerivPower:0
                    for vDerivs in range(1,3)
                    for vDerivPower in range(1,5)
                    if vDerivs+vDerivPower>=2} # dv/dt \approx v^9 / 20
DropvDerivatives.update({'nHatdotv':0}) # \approx - v^7 / 10
SpinComponents = {'SVecdotv':v0*S_lambda, 'SigmaVecdotv':v0*Sigma_lambda,
                  'nHatdotSVec':S_n, 'nHatdotSigmaVec':Sigma_n, }

# %%
Math={}
Sym={}

# %%
def TensorProductCreator(vec,indices):
    try:
        rank = len(indices)
    except TypeError:
        rank = len(indices.name)
    return TensorProduct(*((vec,)*rank))

# %%
class DumbTensor(Symbol):
    _op_priority = 100.0
    @classmethod
    def NewDummy(cls, vecs, coefficient=1):
        d = DumbTensor('*'.join(v.name for v in vecs))
        d.vecs = vecs
        d.coefficient = coefficient
        return d
    def _latex(self, printer):
        return r'\langle '+self.name+r'\rangle '
    def __mul__(self, other):
        if(isinstance(other, DumbTensor)):
            return DumbTensor.NewDummy(self.vecs+other.vecs, self.coefficient*other.coefficient)
        else:
            return DumbTensor.NewDummy(self.vecs, self.coefficient*other)
    def __rmul__(self, other):
        if(isinstance(other, DumbTensor)):
            return DumbTensor.NewDummy(other.vecs+self.vecs, self.coefficient*other.coefficient)
        else:
            return DumbTensor.NewDummy(self.vecs, self.coefficient*other)

class DumbTensor(Symbol):
    _op_priority = 1.0e200
    def __mul__(self, other):
        return DumbTensor('gob('+self.name+'*'+str(other)+')')
    def __rmul__(self, other):
        return DumbTensor('gob('+self.name+'*'+str(other)+')')

def Subscript(vec, indices):
    try:
        indices_str = indices.name
    except AttributeError:
        indices_str = indices
    return TensorProduct([vec,]*len(indices_str), coefficient=1, symmetric=True)
    #return DumbTensor('*'.join(v.name for v in [vec,]*len(indices_str)))
    #return DumbTensor.NewDummy([vec,]*len(indices_str))

# %%
ns = {'Subscript':Subscript, 'DumbTensor':DumbTensor}
ns = locals()

# %%
MathKernel='/Applications/Local/Mathematica.app/Contents/MacOS/MathKernel'

# This little `math` script does the conversion we need.
# It has to output to a temporary file because I know of no
# better way to get the correct format out of Mathematica.
# This whole thing
MathCommand = r"""
    \[Nu] = nu;
    \[Mu] = mu;
    \[CapitalDelta] = delta;
    \[Delta] = delta;
    \[Lambda] = lambda;
    \[CapitalSigma] = Sigma;
    \[Gamma] = gamma;
    \[Epsilon] = epsilon;
    \[Gamma]\[Nu] = gamma*nu;
    \[ScriptL] = ell;
    (*Print[InputForm[ToExpression["{0}", TeXForm]]];*)
    ToExpression["{0}", TeXForm] >> /tmp/Math.cpp;
    Exit[];
"""

# # I believe all the results from this group:
# SrcDir = "source/BlanchetLivRev/"
# MultipoleNames = ["I_ij", "I_ij_A", "I_ij_B", "I_ij_C", "J_ij", "I_ijk", "J_ijk", "I_ijkl", "J_ijkl"]

# # I believe all the results from this group:
# SrcDir = "source/BoheEtAl/eqs/"
# MultipoleNames = ["IijklCMS", "JijklCMS","JijkCMS",]

# # I mostly believe the results from this group, but
# # I don't have the patience to check them all:
# SrcDir = "source/BoheEtAl/eqs/"
# MultipoleNames = ["IijCMS", "JijCMS", "IijkCMS", "JijklCMS",]
SrcDir = "source/BoheEtAl/eqs/"
MultipoleNames = ["JijCMS",]

multiplication = r'\,'

def TensorCreator(coefficient, vector):
    "Used in the regex wars (below)"
    def func(match):
        indices = list(match.group(1))
        if not coefficient:
            return vector + '_{%s}'%match.group(1)
        return vector + '_{%s}'%match.group(1) + multiplication + coefficient + '^{%s}'%len(indices)
    return func

prereplacements = [
    [r'\\\\',r''], # Line breask are meaningless
    [r'&',r''], # Alignments are meaningless
    [r'\\nonumber',r''], # I wasn't gonna anyway
    [r'~',r''], # Explicit spacing is useless
    [r'\\q*uad',r''], # Explicit spacing is useless
    [r'.*?= *',r''],
    [r' *\+ *\\mathcal{O}.*',r''],
    [r'\(n,\\*(Sigma|S) *,v\)',
     r'\mathrm{ndot\1dotv}'], # Catch Bohé et al.'s use of (n,S,v), (n,Sigma,v), for the triple product
    [r'\(\\*(n|v|S|Sigma) *\\*(n|v|S|Sigma) *\)',
     r'\mathrm{\1dot\2}'], # Catch Bohé et al.'s use of (nv), etc., for the dot product
    #[r'\\,', multiplication], # This gets us a good chunk of the way, if we're lucky
    [r'(\\langle|\\rangle|<|>)',r''], # The YlmTensors are already STF
    [r'\\epsilon_\{ab *i\}(.*?)(\{*.\}*)(_.*?)a(.*?)(\{*.\}*)(_.*?)b',
     r'r\,v\,\ell_i\, \1\2\3 \4\5\6 '], # Do the cross product
    [r'\{*x\}*_(\{\}| )', ''], # Remove stubs left from above
    [r'\{*v\}*_(\{\}| )', ''], # Remove stubs left from above
    [r'\\left(\(|\[|\\{)',r'('],
    [r'\\right(\)|\]|\\})',r')'],
    [r'\\(B|b)ig+(\(|\[|\\{)',r'('],
    [r'\\(B|b)ig+(\)|\]|\\})',r')'],
    [r'\\left\.',r''], # Do this BEFORE replacing \left
    [r'\\right\.',r''], # Do this BEFORE replacing \right
    [r'\\left',r''],
    [r'\\right',r''],
    [r'\(\\mathbf{\\*(.*?)}\\times\\mathbf{\\*(.*?)}\)',
     r'\mathrm{\1times\2}'],
    [r'\^\{([ijkl])\}',r'_{\1}'],
    [r'n_{ *(.*?) *}',TensorCreator('', 'n')],
    [r'x_{ *(.*?) *}',TensorCreator('r', 'n')],
    [r'\{x\}_{ *(.*?) *}',TensorCreator('r', 'n')],
    [r'v_{ *(.*?) *}',TensorCreator('v', r'\lambda')],
    [r'\{v\}_{ *(.*?) *}',TensorCreator('v', r'\lambda')],
    [r'  *',r' '], # Tighten up spacing
    [r'\(',r'\,('], # Doesn't hurt to assume multiplication
    [r'([^\\]),',r'\1'], # Remove comma at the end of an equation
    [r'([^\\])\.',r'\1'], # Remove period at the end of an equation
    [r'\\ln *\\*,*',r'\log'],
    ['\\\\',r'\\\\'], # Escape backslashes for Mathematica
    [r"'",r"Prm"],
    #[r"'",r"'\''"], # Pull the ugly command-line single-quote hack AFTER escaping backslashes
]

postreplacements = [
    [r'\^',r'**'],
    [r'lambda',r'lambdaHat'],
    [r'\[',r'('],
    [r'\]',r')'],
    [r'Sigma',r'SigmaVec'],
    [r'S(?!igma|ubscript)',r'SVec'],
    [r'n(?!u)',r'nHat'],
    [r'ell',r'ellHat'],
    #[r'Subscript',r'TensorProductCreator'],
]

for MultipoleName in MultipoleNames:
    print(MultipoleName)
    with open(SrcDir+MultipoleName+".tex", "r") as myfile:
        data=myfile.read().replace('\n', ' ')
    #print("Raw content of {0}:\n".format(MultipoleName)); print(data)
    for replacement in prereplacements:
        data = re.sub(replacement[0], replacement[1], data)
    #print("\nbecomes\n"); print("""'{0}'""".format(data))
    #! echo '{MathCommand.format(data)}'
    #continue # Skip Mathematica stuff for now
    ! {MathKernel} -run '{MathCommand.format(data)}' >& /dev/null
    MathTmp = !cat /tmp/Math.cpp
    Math[MultipoleName] = ''.join(MathTmp)#.replace('^','**').replace('lambda','lambdaHat').replace('[','(').replace(']',')')
    for replacement in postreplacements:
        Math[MultipoleName] = re.sub(replacement[0], replacement[1], Math[MultipoleName])
    print("\nbecomes\n"); print(Math[MultipoleName]); print("\nbecomes\n")
    Sym[MultipoleName] = sympify(Math[MultipoleName], ns)
    display(Sym[MultipoleName])
    print("  reduces to")
    Sym[MultipoleName] = ReduceExpr(Sym[MultipoleName])
    display(Sym[MultipoleName])
    print("\n\n")
# Out:
# JijCMS
# becomes
#
# (-3*nu*r*Subscript(nHat, j)*Subscript(SigmaVec, i))/(2*c) +  (nu*r*((-11*delta*nHatdotSVec*v**2*Subscript(lambdaHat, i)*Subscript(lambdaHat, j))/14 +     nHatdotSigmaVec*(-11/14 + (47*nu)/14)*v**2*Subscript(lambdaHat, i)*     Subscript(lambdaHat, j) + (33*delta*SVecdotv*v*Subscript(lambdaHat, j)*      Subscript(nHat, i))/28 + (33/28 - (155*nu)/28)*SigmaVecdotv*v*     Subscript(lambdaHat, j)*Subscript(nHat, i) +     (3*delta*nHatdotv*v*Subscript(lambdaHat, j)*Subscript(SVec, i))/7 -     (2*delta*v**2*Subscript(nHat, j)*Subscript(SVec, i))/7 +     nHatdotv*(3/7 - (16*nu)/7)*v*Subscript(lambdaHat, j)*Subscript(SigmaVec, i) +     (-29/28 + (143*nu)/28)*v**2*Subscript(nHat, j)*Subscript(SigmaVec, i) +     (Gm*((-29*delta*nHatdotSVec*Subscript(nHat, i)*Subscript(nHat, j))/14 +        nHatdotSigmaVec*(-4/7 + (31*nu)/14)*Subscript(nHat, i)*Subscript(nHat, j) +        (10*delta*Subscript(nHat, j)*Subscript(SVec, i))/7 +        (61/28 - (71*nu)/28)*Subscript(nHat, j)*Subscript(SigmaVec, i)))/r))/c**3 +  (nu*r*(delta*nHatdotv*(5/84 - (5*nu)/42)*SVecdotv*v**2*Subscript(lambdaHat, i)*     Subscript(lambdaHat, j) + nHatdotv*(5/84 - (10*nu)/21 + (5*nu**2)/6)*SigmaVecdotv*     v**2*Subscript(lambdaHat, i)*Subscript(lambdaHat, j) +     delta*nHatdotSVec*(-41/84 + (181*nu)/84)*v**4*Subscript(lambdaHat, i)*     Subscript(lambdaHat, j) + nHatdotSigmaVec*(-41/84 + (55*nu)/12 - (443*nu**2)/42)*     v**4*Subscript(lambdaHat, i)*Subscript(lambdaHat, j) +     delta*(269/336 - (283*nu)/84)*SVecdotv*v**3*Subscript(lambdaHat, j)*     Subscript(nHat, i) + (269/336 - (2587*nu)/336 + (6001*nu**2)/336)*SigmaVecdotv*     v**3*Subscript(lambdaHat, j)*Subscript(nHat, i) +     delta*nHatdotv*(13/42 - (53*nu)/42)*v**3*Subscript(lambdaHat, j)*     Subscript(SVec, i) + delta*(-4/21 + (17*nu)/21)*v**4*Subscript(nHat, j)*     Subscript(SVec, i) + nHatdotv*(13/42 - (125*nu)/42 + (293*nu**2)/42)*v**3*     Subscript(lambdaHat, j)*Subscript(SigmaVec, i) +     (-253/336 + (2435*nu)/336 - (5633*nu**2)/336)*v**4*Subscript(nHat, j)*     Subscript(SigmaVec, i) +     (G**2*m**2*(delta*nHatdotSVec*(407/126 - (37*nu)/126)*Subscript(nHat, i)*        Subscript(nHat, j) + nHatdotSigmaVec*(155/126 - (311*nu)/63 - (877*nu**2)/252)*        Subscript(nHat, i)*Subscript(nHat, j) + delta*(-103/63 - (25*nu)/63)*        Subscript(nHat, j)*Subscript(SVec, i) + (-275/504 + (3895*nu)/504 +          (1571*nu**2)/504)*Subscript(nHat, j)*Subscript(SigmaVec, i)))/r**2 +     (Gm*(delta*nHatdotSVec*(103/126 - (751*nu)/252)*v**2*Subscript(lambdaHat, i)*        Subscript(lambdaHat, j) + nHatdotSigmaVec*(-275/126 + (1193*nu)/252 +          (691*nu**2)/63)*v**2*Subscript(lambdaHat, i)*Subscript(lambdaHat, j) +        delta*nHatdotSVec*nHatdotv*(-317/126 - (497*nu)/72)*v*Subscript(lambdaHat, j)*        Subscript(nHat, i) + nHatdotSigmaVec*nHatdotv*(-173/126 + (2389*nu)/504 +          (1073*nu**2)/126)*v*Subscript(lambdaHat, j)*Subscript(nHat, i) +        delta*(5/504 + (1649*nu)/504)*SVecdotv*v*Subscript(lambdaHat, j)*        Subscript(nHat, i) + (2021/504 - (3347*nu)/252 - (4127*nu**2)/504)*        SigmaVecdotv*v*Subscript(lambdaHat, j)*Subscript(nHat, i) +        delta*nHatdotv*(331/252 + (2549*nu)/504)*SVecdotv*Subscript(nHat, i)*        Subscript(nHat, j) + nHatdotv*(-101/252 + (449*nu)/72 - (2789*nu**2)/126)*        SigmaVecdotv*Subscript(nHat, i)*Subscript(nHat, j) +        nHatdotSVec*(delta*nHatdotv**2*(23/168 + (415*nu)/84) +          delta*(-617/504 + (809*nu)/252)*v**2)*Subscript(nHat, i)*        Subscript(nHat, j) + nHatdotSigmaVec*(nHatdotv**2*(-13/168 + (569*nu)/168 -            (2147*nu**2)/168) + (229/504 - (1703*nu)/504 + (2795*nu**2)/504)*          v**2)*Subscript(nHat, i)*Subscript(nHat, j) +        delta*nHatdotv*(7/9 + (160*nu)/63)*v*Subscript(lambdaHat, j)*        Subscript(SVec, i) + (delta*nHatdotv**2*(-115/126 - (487*nu)/126) +          delta*(125/63 - (157*nu)/63)*v**2)*Subscript(nHat, j)*Subscript(SVec, i) +        nHatdotv*(131/504 - (4741*nu)/504 - (5837*nu**2)/504)*v*       ...
#
# becomes
# TensorProductFunction₃₇₅(t)   TensorFunction₇₆(t)   TensorFunction₁₁₃(t)
# ─────────────────────────── + ─────────────────── + ────────────────────
#             2⋅c                         3                     5
#                                        c                     c
#   reduces to
# TensorFunction₁₁₉(t)

# %%
V_L = Sym[MultipoleName]
for i in range(V_L.rank):
    V_L = diff(V_L, t)
    V_L = V_L.xreplace(SimplifyVectorDerivatives).subs(dict(DropvDerivatives.items() + {diff(v,t): v**9/20}.items())).subs(SpinComponents)
V_L = V_L.subs(t,0).subs({v.subs(t,0):v0}) )

# %%
ell = V_L.rank
for m in range(-ell,ell+1):
    print(ell,m)
    tmp = simplify( sphericalharmonictensors.Vlm(V_L,2)
    lazy_series = tmp.lseries(v0, 0)
    for i_term in range(3):
        term = lazy_series.next().simplify()
        display(term)
# Out:
# 2 -2
#   ____   ___   ⎛          ⎛      2  2    8             2  2  8
# ╲╱ 10 ⋅╲╱ π ⋅ν⋅⎝- 8⋅S_λ⋅δ⋅⎝7000⋅G ⋅m ⋅ν⋅v (0) + 28840⋅G ⋅m ⋅v (0) - 10800⋅Gm⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2  6                       2    6                      2  6
#  ⋅v (0) + 29220⋅Gm⋅nHatdotv ⋅ν⋅v (0) + 6900⋅Gm⋅nHatdotv ⋅v (0) - 2880⋅Gm⋅nHatd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        12                            2                       12
# otv⋅ν⋅v  (0) + 128000⋅Gm⋅nHatdotv⋅ν⋅v (0) - 882⋅Gm⋅nHatdotv⋅v  (0) + 39200⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           2                  8                8           2           10
# nHatdotv⋅v (0) + 43960⋅Gm⋅ν⋅v (0) - 35000⋅Gm⋅v (0) + 378⋅c ⋅nHatdotv⋅v  (0) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2                  2  6                       12
# 21600⋅c ⋅nHatdotv + 2160⋅c ⋅v (0) + 1431⋅nHatdotv⋅ν⋅v  (0) - 63600⋅nHatdotv⋅ν⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2                    12                      2               8            8
# v (0) - 351⋅nHatdotv⋅v  (0) + 15600⋅nHatdotv⋅v (0) - 14280⋅ν⋅v (0) + 3360⋅v (0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  ⎞                    ⎛    2  2    12            2  2    2           2  2  12
# )⎠⋅v(0) + 160⋅ⅈ⋅S_λ⋅δ⋅⎝50⋅G ⋅m ⋅ν⋅v  (0) - 1000⋅G ⋅m ⋅ν⋅v (0) + 206⋅G ⋅m ⋅v  (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  2  2               2                   2                     2
# 0) - 4120⋅G ⋅m ⋅v (0) + 3600⋅Gm⋅c  - 9740⋅Gm⋅nHatdotv ⋅ν - 2300⋅Gm⋅nHatdotv  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                      6                       6                12
#  1600⋅Gm⋅nHatdotv⋅ν⋅v (0) + 490⋅Gm⋅nHatdotv⋅v (0) + 314⋅Gm⋅ν⋅v  (0) - 6280⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2              12               2          2           4           2
# ν⋅v (0) - 250⋅Gm⋅v  (0) + 5000⋅Gm⋅v (0) + 54⋅c ⋅nHatdotv⋅v (0) - 720⋅c  - 795⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             6                    6             12              2          12
# nHatdotv⋅ν⋅v (0) + 195⋅nHatdotv⋅v (0) - 102⋅ν⋅v  (0) + 2040⋅ν⋅v (0) + 24⋅v  (0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          2   ⎞  2                ⎛      2  2    8             2  2  8
# ) - 480⋅v (0)⎠⋅v (0) + 8⋅ⅈ⋅S_n⋅δ⋅⎝7000⋅G ⋅m ⋅ν⋅v (0) + 28840⋅G ⋅m ⋅v (0) - 108
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2  6                       2    6                      2  6
# 00⋅Gm⋅c ⋅v (0) + 29220⋅Gm⋅nHatdotv ⋅ν⋅v (0) + 6900⋅Gm⋅nHatdotv ⋅v (0) - 2880⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               12                            2                       12
# m⋅nHatdotv⋅ν⋅v  (0) + 128000⋅Gm⋅nHatdotv⋅ν⋅v (0) - 882⋅Gm⋅nHatdotv⋅v  (0) + 39
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2                  8                8           2           1
# 200⋅Gm⋅nHatdotv⋅v (0) + 43960⋅Gm⋅ν⋅v (0) - 35000⋅Gm⋅v (0) + 378⋅c ⋅nHatdotv⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 0             2                  2  6                       12
#  (0) + 21600⋅c ⋅nHatdotv + 2160⋅c ⋅v (0) + 1431⋅nHatdotv⋅ν⋅v  (0) - 63600⋅nHat
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2                    12                      2               8
# dotv⋅ν⋅v (0) - 351⋅nHatdotv⋅v  (0) + 15600⋅nHatdotv⋅v (0) - 14280⋅ν⋅v (0) + 33
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     8   ⎞                  ⎛    2  2    12            2  2    2           2  2
# 60⋅v (0)⎠⋅v(0) + 160⋅S_n⋅δ⋅⎝50⋅G ⋅m ⋅ν⋅v  (0) - 1000⋅G ⋅m ⋅ν⋅v (0) + 206⋅G ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   12            2  2  2               2                   2
# ⋅v  (0) - 4120⋅G ⋅m ⋅v (0) + 3600⋅Gm⋅c  - 9740⋅Gm⋅nHatdotv ⋅ν - 2300⋅Gm⋅nHatdo
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                       6                       6                12
# tv  + 1600⋅Gm⋅nHatdotv⋅ν⋅v (0) + 490⋅Gm⋅nHatdotv⋅v (0) + 314⋅Gm⋅ν⋅v  (0) - 628
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2              12               2          2           4           2
# 0⋅Gm⋅ν⋅v (0) - 250⋅Gm⋅v  (0) + 5000⋅Gm⋅v (0) + 54⋅c ⋅nHatdotv⋅v (0) - 720⋅c  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  6                    6             12              2
#  795⋅nHatdotv⋅ν⋅v (0) + 195⋅nHatdotv⋅v (0) - 102⋅ν⋅v  (0) + 2040⋅ν⋅v (0) + 24⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  12           2   ⎞  2            ⎛        2  2  2  8              2  2    8
# v  (0) - 480⋅v (0)⎠⋅v (0) + 2⋅Σ_λ⋅⎝219940⋅G ⋅m ⋅ν ⋅v (0) + 545300⋅G ⋅m ⋅ν⋅v (0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  2  8                2    6                2  6
# ) - 38500⋅G ⋅m ⋅v (0) - 76680⋅Gm⋅c ⋅ν⋅v (0) + 65880⋅Gm⋅c ⋅v (0) + 757410⋅Gm⋅nH
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2  2  6                        2    6                       2  6
# atdotv ⋅ν ⋅v (0) - 315870⋅Gm⋅nHatdotv ⋅ν⋅v (0) + 34230⋅Gm⋅nHatdotv ⋅v (0) - 52
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2  12                           2  2
# 533⋅Gm⋅nHatdotv⋅ν ⋅v  (0) + 2334800⋅Gm⋅nHatdotv⋅ν ⋅v (0) - 42669⋅Gm⋅nHatdotv⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   12                             2                        12
# ⋅v  (0) + 1896400⋅Gm⋅nHatdotv⋅ν⋅v (0) + 1179⋅Gm⋅nHatdotv⋅v  (0) - 52400⋅Gm⋅nHa
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2                 2  8                    8                 8
# tdotv⋅v (0) + 490630⋅Gm⋅ν ⋅v (0) + 1288910⋅Gm⋅ν⋅v (0) - 222250⋅Gm⋅v (0) + 1512
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    4  4            2             10              2                    2
# 0⋅c ⋅v (0) + 8064⋅c ⋅nHatdotv⋅ν⋅v  (0) + 460800⋅c ⋅nHatdotv⋅ν - 1512⋅c ⋅nHatdo
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     10             2                    2    6             2  6
# tv⋅v  (0) - 86400⋅c ⋅nHatdotv + 154440⋅c ⋅ν⋅v (0) - 31320⋅c ⋅v (0) + 31644⋅nHa
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2  12                        2  2                        12
# tdotv⋅ν ⋅v  (0) - 1406400⋅nHatdotv⋅ν ⋅v (0) - 13500⋅nHatdotv⋅ν⋅v  (0) + 600000
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#              2                     12                      2               2
# ⋅nHatdotv⋅ν⋅v (0) + 1404⋅nHatdotv⋅v  (0) - 62400⋅nHatdotv⋅v (0) - 1182930⋅ν ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 8                8             8   ⎞                ⎛       2  2  2  14
#  (0) + 511350⋅ν⋅v (0) - 53130⋅v (0)⎠⋅v(0) - 4⋅ⅈ⋅Σ_λ⋅⎝15710⋅G ⋅m ⋅ν ⋅v  (0) - 3
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2  2  2  4             2  2    14              2  2    4            2
# 14200⋅G ⋅m ⋅ν ⋅v (0) + 38950⋅G ⋅m ⋅ν⋅v  (0) - 779000⋅G ⋅m ⋅ν⋅v (0) - 2750⋅G ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2  14             2  2  4                 2    2                 2  2
#  ⋅v  (0) + 55000⋅G ⋅m ⋅v (0) + 255600⋅Gm⋅c ⋅ν⋅v (0) - 219600⋅Gm⋅c ⋅v (0) - 252
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2  2  2                         2    2
# 4700⋅Gm⋅nHatdotv ⋅ν ⋅v (0) + 1052900⋅Gm⋅nHatdotv ⋅ν⋅v (0) - 114100⋅Gm⋅nHatdotv
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2  2                          2  8                            8
#  ⋅v (0) + 291850⋅Gm⋅nHatdotv⋅ν ⋅v (0) + 237050⋅Gm⋅nHatdotv⋅ν⋅v (0) - 6550⋅Gm⋅n
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          8                2  14                 2  4                  14
# Hatdotv⋅v (0) + 35045⋅Gm⋅ν ⋅v  (0) - 700900⋅Gm⋅ν ⋅v (0) + 92065⋅Gm⋅ν⋅v  (0) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               4                14                 4            4  10
# 1841300⋅Gm⋅ν⋅v (0) - 15875⋅Gm⋅v  (0) + 317500⋅Gm⋅v (0) + 4536⋅c ⋅v  (0) + 1512
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     4          2             6            2           6              2    2
# 00⋅c  + 11520⋅c ⋅nHatdotv⋅ν⋅v (0) - 2160⋅c ⋅nHatdotv⋅v (0) - 514800⋅c ⋅ν⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  2                       2  8                        8
#  + 104400⋅c ⋅v (0) - 175800⋅nHatdotv⋅ν ⋅v (0) + 75000⋅nHatdotv⋅ν⋅v (0) - 7800⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           8             2  14               2  4               14
# nHatdotv⋅v (0) - 84495⋅ν ⋅v  (0) + 1689900⋅ν ⋅v (0) + 36525⋅ν⋅v  (0) - 730500⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    4            14             4   ⎞           ⎛        2  2  2  8
# ν⋅v (0) - 3795⋅v  (0) + 75900⋅v (0)⎠ - 2⋅ⅈ⋅Σ_n⋅⎝219940⋅G ⋅m ⋅ν ⋅v (0) + 545300
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2  2    8             2  2  8                2    6                2  6
# ⋅G ⋅m ⋅ν⋅v (0) - 38500⋅G ⋅m ⋅v (0) - 76680⋅Gm⋅c ⋅ν⋅v (0) + 65880⋅Gm⋅c ⋅v (0) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2  2  6                        2    6
#  757410⋅Gm⋅nHatdotv ⋅ν ⋅v (0) - 315870⋅Gm⋅nHatdotv ⋅ν⋅v (0) + 34230⋅Gm⋅nHatdot
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2  6                         2  12                           2  2
# v ⋅v (0) - 52533⋅Gm⋅nHatdotv⋅ν ⋅v  (0) + 2334800⋅Gm⋅nHatdotv⋅ν ⋅v (0) - 42669⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                12                             2                        12
# Gm⋅nHatdotv⋅ν⋅v  (0) + 1896400⋅Gm⋅nHatdotv⋅ν⋅v (0) + 1179⋅Gm⋅nHatdotv⋅v  (0) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     2                 2  8                    8
#  52400⋅Gm⋅nHatdotv⋅v (0) + 490630⋅Gm⋅ν ⋅v (0) + 1288910⋅Gm⋅ν⋅v (0) - 222250⋅Gm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   8             4  4            2             10              2
# ⋅v (0) + 15120⋅c ⋅v (0) + 8064⋅c ⋅nHatdotv⋅ν⋅v  (0) + 460800⋅c ⋅nHatdotv⋅ν - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      2           10             2                    2    6             2  6
# 512⋅c ⋅nHatdotv⋅v  (0) - 86400⋅c ⋅nHatdotv + 154440⋅c ⋅ν⋅v (0) - 31320⋅c ⋅v (0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     2  12                        2  2                        1
# ) + 31644⋅nHatdotv⋅ν ⋅v  (0) - 1406400⋅nHatdotv⋅ν ⋅v (0) - 13500⋅nHatdotv⋅ν⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                         2                     12                      2
#  (0) + 600000⋅nHatdotv⋅ν⋅v (0) + 1404⋅nHatdotv⋅v  (0) - 62400⋅nHatdotv⋅v (0) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           2  8                8             8   ⎞              ⎛       2  2  2
#  1182930⋅ν ⋅v (0) + 511350⋅ν⋅v (0) - 53130⋅v (0)⎠⋅v(0) - 4⋅Σ_n⋅⎝15710⋅G ⋅m ⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   14              2  2  2  4             2  2    14              2  2    4
# ⋅v  (0) - 314200⋅G ⋅m ⋅ν ⋅v (0) + 38950⋅G ⋅m ⋅ν⋅v  (0) - 779000⋅G ⋅m ⋅ν⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2  2  14             2  2  4                 2    2                 2
# - 2750⋅G ⋅m ⋅v  (0) + 55000⋅G ⋅m ⋅v (0) + 255600⋅Gm⋅c ⋅ν⋅v (0) - 219600⋅Gm⋅c ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2                         2  2  2                         2    2
# v (0) - 2524700⋅Gm⋅nHatdotv ⋅ν ⋅v (0) + 1052900⋅Gm⋅nHatdotv ⋅ν⋅v (0) - 114100⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  2                          2  8                            8
# Gm⋅nHatdotv ⋅v (0) + 291850⋅Gm⋅nHatdotv⋅ν ⋅v (0) + 237050⋅Gm⋅nHatdotv⋅ν⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     8                2  14                 2  4
# - 6550⋅Gm⋅nHatdotv⋅v (0) + 35045⋅Gm⋅ν ⋅v  (0) - 700900⋅Gm⋅ν ⋅v (0) + 92065⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    14                    4                14                 4            4  1
# ν⋅v  (0) - 1841300⋅Gm⋅ν⋅v (0) - 15875⋅Gm⋅v  (0) + 317500⋅Gm⋅v (0) + 4536⋅c ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 0              4          2             6            2           6
#  (0) + 151200⋅c  + 11520⋅c ⋅nHatdotv⋅ν⋅v (0) - 2160⋅c ⋅nHatdotv⋅v (0) - 514800
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2    2              2  2                       2  8                        8
# ⋅c ⋅ν⋅v (0) + 104400⋅c ⋅v (0) - 175800⋅nHatdotv⋅ν ⋅v (0) + 75000⋅nHatdotv⋅ν⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                      8             2  14               2  4               14
# (0) - 7800⋅nHatdotv⋅v (0) - 84495⋅ν ⋅v  (0) + 1689900⋅ν ⋅v (0) + 36525⋅ν⋅v  (0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               4            14             4   ⎞   ⎛          2    2
# ) - 730500⋅ν⋅v (0) - 3795⋅v  (0) + 75900⋅v (0)⎠ + ⎝- 236800⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2               2    2            2               2  2                2  2
# ν⋅v (0) + 2604800⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅v (0) - 2806400⋅G ⋅m ⋅nHatdotSigma⃗⋅ν ⋅v (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2  2                  2              2  2                2
# 0) - 3980800⋅G ⋅m ⋅nHatdotSigma⃗⋅ν⋅v (0) + 992000⋅G ⋅m ⋅nHatdotSigma⃗⋅v (0) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# 4078400⋅Gm⋅SVecdotv⋅δ⋅nHatdotv⋅ν + 1059200⋅Gm⋅SVecdotv⋅δ⋅nHatdotv + 329800⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               6                          6
# SVecdotv⋅δ⋅ν⋅v (0) + 1000⋅Gm⋅SVecdotv⋅δ⋅v (0) - 17849600⋅Gm⋅SigmaVecdotv⋅nHatd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      2
# otv⋅ν  + 5028800⋅Gm⋅SigmaVecdotv⋅nHatdotv⋅ν - 323200⋅Gm⋅SigmaVecdotv⋅nHatdotv
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                           2  6                                 6
# - 825400⋅Gm⋅SigmaVecdotv⋅ν ⋅v (0) - 1338800⋅Gm⋅SigmaVecdotv⋅ν⋅v (0) + 404200⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 6                  2                           2
# m⋅SigmaVecdotv⋅v (0) - 1670400⋅Gm⋅c ⋅δ⋅nHatdotS⃗ + 1785600⋅Gm⋅c ⋅nHatdotSigma⃗
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2                                                2
# ⋅ν - 460800⋅Gm⋅c ⋅nHatdotSigma⃗ + 3984000⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv ⋅ν + 110400⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                        2                                     6
# Gm⋅δ⋅nHatdotS⃗⋅nHatdotv  - 695800⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅ν⋅v (0) - 253600⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                       6                              12
# δ⋅nHatdotS⃗⋅nHatdotv⋅v (0) - 60080⋅Gm⋅δ⋅nHatdotS⃗⋅ν⋅v  (0) + 4992000⋅Gm⋅δ⋅nHat
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          2                            12                              2
# dotS⃗⋅ν⋅v (0) + 16480⋅Gm⋅δ⋅nHatdotS⃗⋅v  (0) - 1646400⋅Gm⋅δ⋅nHatdotS⃗⋅v (0) - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                  2  2                                    2
# 0305600⋅Gm⋅nHatdotSigma⃗⋅nHatdotv ⋅ν  + 2731200⋅Gm⋅nHatdotSigma⃗⋅nHatdotv ⋅ν -
# ──────────────────────────────────────────────────────────────────────────────
#                                               5
#                                       756000⋅c
#
#                                 2                                     2  6
#  62400⋅Gm⋅nHatdotSigma⃗⋅nHatdotv  + 858400⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅ν ⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                       6
# + 477800⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅ν⋅v (0) - 138400⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  6                               2  12                                2  2
# v (0) + 221120⋅Gm⋅nHatdotSigma⃗⋅ν ⋅v  (0) - 4372800⋅Gm⋅nHatdotSigma⃗⋅ν ⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             12                                  2
# + 95440⋅Gm⋅nHatdotSigma⃗⋅ν⋅v  (0) - 6542400⋅Gm⋅nHatdotSigma⃗⋅ν⋅v (0) - 44000⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  12                                2                      2
# m⋅nHatdotSigma⃗⋅v  (0) + 2126400⋅Gm⋅nHatdotSigma⃗⋅v (0) + 23760⋅SVecdotv⋅c ⋅δ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  4
# v (0) + 96000⋅SVecdotv⋅δ⋅nHatdotv⋅ν - 48000⋅SVecdotv⋅δ⋅nHatdotv - 339600⋅SVecd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          6                        6                           2    4
# otv⋅δ⋅ν⋅v (0) + 80700⋅SVecdotv⋅δ⋅v (0) - 111600⋅SigmaVecdotv⋅c ⋅ν⋅v (0) + 2376
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2  4                                    2
# 0⋅SigmaVecdotv⋅c ⋅v (0) - 672000⋅SigmaVecdotv⋅nHatdotv⋅ν  + 384000⋅SigmaVecdot
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                    2  6
# v⋅nHatdotv⋅ν - 48000⋅SigmaVecdotv⋅nHatdotv + 1800300⋅SigmaVecdotv⋅ν ⋅v (0) - 7
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                       6                          6              2
# 76100⋅SigmaVecdotv⋅ν⋅v (0) + 80700⋅SigmaVecdotv⋅v (0) + 633600⋅c ⋅δ⋅nHatdotS⃗
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2                           2
# - 2707200⋅c ⋅nHatdotSigma⃗⋅ν + 633600⋅c ⋅nHatdotSigma⃗ + 43440⋅δ⋅nHatdotS⃗⋅ν⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 12                             2                        12
#   (0) - 1737600⋅δ⋅nHatdotS⃗⋅ν⋅v (0) - 9840⋅δ⋅nHatdotS⃗⋅v  (0) + 393600⋅δ⋅nHatd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2                            2  12                             2  2
# otS⃗⋅v (0) - 212640⋅nHatdotSigma⃗⋅ν ⋅v  (0) + 8505600⋅nHatdotSigma⃗⋅ν ⋅v (0) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                         12                               2
#  92400⋅nHatdotSigma⃗⋅ν⋅v  (0) - 3696000⋅nHatdotSigma⃗⋅ν⋅v (0) - 9840⋅nHatdotSi
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       12                            2   ⎞  2      ⎛      2    2              1
# gma⃗⋅v  (0) + 393600⋅nHatdotSigma⃗⋅v (0)⎠⋅v (0) + ⎝5920⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅ν⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2              2    2              2             2    2            12
#  (0) - 236800⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅ν⋅v (0) - 65120⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅v  (0) + 260
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2    2            2             2  2                2  12
# 4800⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅v (0) + 70160⋅G ⋅m ⋅nHatdotSigma⃗⋅ν ⋅v  (0) - 2806400⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2  2                2  2             2  2                  12               2
#  ⋅m ⋅nHatdotSigma⃗⋅ν ⋅v (0) + 99520⋅G ⋅m ⋅nHatdotSigma⃗⋅ν⋅v  (0) - 3980800⋅G ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2                  2             2  2                12              2  2
# m ⋅nHatdotSigma⃗⋅ν⋅v (0) - 24800⋅G ⋅m ⋅nHatdotSigma⃗⋅v  (0) + 992000⋅G ⋅m ⋅nHa
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             2
# tdotSigma⃗⋅v (0) + 4078400⋅Gm⋅SVecdotv⋅δ⋅nHatdotv⋅ν + 1059200⋅Gm⋅SVecdotv⋅δ⋅nH
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                  6                          6
# atdotv + 329800⋅Gm⋅SVecdotv⋅δ⋅ν⋅v (0) + 1000⋅Gm⋅SVecdotv⋅δ⋅v (0) - 17849600⋅Gm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                         2
# ⋅SigmaVecdotv⋅nHatdotv⋅ν  + 5028800⋅Gm⋅SigmaVecdotv⋅nHatdotv⋅ν - 323200⋅Gm⋅Sig
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                              2  6
# maVecdotv⋅nHatdotv - 825400⋅Gm⋅SigmaVecdotv⋅ν ⋅v (0) - 1338800⋅Gm⋅SigmaVecdotv
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     6                              6                  2
# ⋅ν⋅v (0) + 404200⋅Gm⋅SigmaVecdotv⋅v (0) - 1670400⋅Gm⋅c ⋅δ⋅nHatdotS⃗ + 1785600⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                              2
# Gm⋅c ⋅nHatdotSigma⃗⋅ν - 460800⋅Gm⋅c ⋅nHatdotSigma⃗ + 3984000⋅Gm⋅δ⋅nHatdotS⃗⋅nH
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2                                   2
# atdotv ⋅ν + 110400⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv  - 695800⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   6                                      6                              12
# ⋅v (0) - 253600⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅v (0) - 64720⋅Gm⋅δ⋅nHatdotS⃗⋅ν⋅v  (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             2                            12
# + 4992000⋅Gm⋅δ⋅nHatdotS⃗⋅ν⋅v (0) + 24680⋅Gm⋅δ⋅nHatdotS⃗⋅v  (0) - 1646400⋅Gm⋅δ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2                                        2  2
# nHatdotS⃗⋅v (0) - 10305600⋅Gm⋅nHatdotSigma⃗⋅nHatdotv ⋅ν  + 2731200⋅Gm⋅nHatdotS
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2                                    2
# igma⃗⋅nHatdotv ⋅ν - 62400⋅Gm⋅nHatdotSigma⃗⋅nHatdotv  + 858400⋅Gm⋅nHatdotSigma⃗
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  6                                          6
# ⋅nHatdotv⋅ν ⋅v (0) + 477800⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅ν⋅v (0) - 138400⋅Gm⋅nHat
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     6                               2  12
# dotSigma⃗⋅nHatdotv⋅v (0) - 111800⋅Gm⋅nHatdotSigma⃗⋅ν ⋅v  (0) - 4372800⋅Gm⋅nHat
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  2                                12
# dotSigma⃗⋅ν ⋅v (0) + 68120⋅Gm⋅nHatdotSigma⃗⋅ν⋅v  (0) - 6542400⋅Gm⋅nHatdotSigma
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      2                             12                                2
# ⃗⋅ν⋅v (0) - 9160⋅Gm⋅nHatdotSigma⃗⋅v  (0) + 2126400⋅Gm⋅nHatdotSigma⃗⋅v (0) + 23
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2    4
# 760⋅SVecdotv⋅c ⋅δ⋅v (0) + 96000⋅SVecdotv⋅δ⋅nHatdotv⋅ν - 48000⋅SVecdotv⋅δ⋅nHatd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                            6                        6
# otv - 339600⋅SVecdotv⋅δ⋅ν⋅v (0) + 80700⋅SVecdotv⋅δ⋅v (0) - 111600⋅SigmaVecdotv
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2    4                          2  4                                    2
# ⋅c ⋅ν⋅v (0) + 23760⋅SigmaVecdotv⋅c ⋅v (0) - 672000⋅SigmaVecdotv⋅nHatdotv⋅ν  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# 384000⋅SigmaVecdotv⋅nHatdotv⋅ν - 48000⋅SigmaVecdotv⋅nHatdotv + 1800300⋅SigmaVe
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2  6                             6                          6
# cdotv⋅ν ⋅v (0) - 776100⋅SigmaVecdotv⋅ν⋅v (0) + 80700⋅SigmaVecdotv⋅v (0) + 6336
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                        2                           2
# 00⋅c ⋅δ⋅nHatdotS⃗ - 2707200⋅c ⋅nHatdotSigma⃗⋅ν + 633600⋅c ⋅nHatdotSigma⃗ - 173
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     2                          2                             2
# 7600⋅δ⋅nHatdotS⃗⋅ν⋅v (0) + 393600⋅δ⋅nHatdotS⃗⋅v (0) + 8505600⋅nHatdotSigma⃗⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                               2                            2   ⎞  2
# ⋅v (0) - 3696000⋅nHatdotSigma⃗⋅ν⋅v (0) + 393600⋅nHatdotSigma⃗⋅v (0)⎠⋅v (0) + ⅈ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  ⎛       2    2              8              2    2            8              2
# ⋅⎝82880⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅ν⋅v (0) - 911680⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅v (0) + 982240⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                2  8               2  2                  8              2
# ⋅m ⋅nHatdotSigma⃗⋅ν ⋅v (0) + 1393280⋅G ⋅m ⋅nHatdotSigma⃗⋅ν⋅v (0) - 347200⋅G ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                8                                       6
#  ⋅nHatdotSigma⃗⋅v (0) - 611760⋅Gm⋅SVecdotv⋅δ⋅nHatdotv⋅ν⋅v (0) - 158880⋅Gm⋅SVec
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  6                             12
# dotv⋅δ⋅nHatdotv⋅v (0) - 29682⋅Gm⋅SVecdotv⋅δ⋅ν⋅v  (0) + 5276800⋅Gm⋅SVecdotv⋅δ⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                        12                           2
# ...
#
#
#               2    4
# 760⋅SVecdotv⋅c ⋅δ⋅v (0) + 96000⋅SVecdotv⋅δ⋅nHatdotv⋅ν - 48000⋅SVecdotv⋅δ⋅nHatd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                            6                        6
# otv - 339600⋅SVecdotv⋅δ⋅ν⋅v (0) + 80700⋅SVecdotv⋅δ⋅v (0) - 111600⋅SigmaVecdotv
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2    4                          2  4                                    2
# ⋅c ⋅ν⋅v (0) + 23760⋅SigmaVecdotv⋅c ⋅v (0) - 672000⋅SigmaVecdotv⋅nHatdotv⋅ν  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# 384000⋅SigmaVecdotv⋅nHatdotv⋅ν - 48000⋅SigmaVecdotv⋅nHatdotv + 1800300⋅SigmaVe
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2  6                             6                          6
# cdotv⋅ν ⋅v (0) - 776100⋅SigmaVecdotv⋅ν⋅v (0) + 80700⋅SigmaVecdotv⋅v (0) + 6336
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                        2                           2
# 00⋅c ⋅δ⋅nHatdotS⃗ - 2707200⋅c ⋅nHatdotSigma⃗⋅ν + 633600⋅c ⋅nHatdotSigma⃗ - 173
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     2                          2                             2
# 7600⋅δ⋅nHatdotS⃗⋅ν⋅v (0) + 393600⋅δ⋅nHatdotS⃗⋅v (0) + 8505600⋅nHatdotSigma⃗⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                               2                            2   ⎞  2
# ⋅v (0) - 3696000⋅nHatdotSigma⃗⋅ν⋅v (0) + 393600⋅nHatdotSigma⃗⋅v (0)⎠⋅v (0) - ⅈ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  ⎛       2    2              8              2    2            8              2
# ⋅⎝82880⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅ν⋅v (0) - 911680⋅G ⋅δ⋅m ⋅nHatdotS⃗⋅v (0) + 982240⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                2  8               2  2                  8              2
# ⋅m ⋅nHatdotSigma⃗⋅ν ⋅v (0) + 1393280⋅G ⋅m ⋅nHatdotSigma⃗⋅ν⋅v (0) - 347200⋅G ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                8                                       6
#  ⋅nHatdotSigma⃗⋅v (0) - 611760⋅Gm⋅SVecdotv⋅δ⋅nHatdotv⋅ν⋅v (0) - 158880⋅Gm⋅SVec
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  6                             12
# dotv⋅δ⋅nHatdotv⋅v (0) - 29682⋅Gm⋅SVecdotv⋅δ⋅ν⋅v  (0) + 5276800⋅Gm⋅SVecdotv⋅δ⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                        12                           2
# ⋅v (0) - 90⋅Gm⋅SVecdotv⋅δ⋅v  (0) + 16000⋅Gm⋅SVecdotv⋅δ⋅v (0) + 2677440⋅Gm⋅Sigm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2  6                                         6
# aVecdotv⋅nHatdotv⋅ν ⋅v (0) - 754320⋅Gm⋅SigmaVecdotv⋅nHatdotv⋅ν⋅v (0) + 48480⋅G
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          6                             2  12
# m⋅SigmaVecdotv⋅nHatdotv⋅v (0) + 74286⋅Gm⋅SigmaVecdotv⋅ν ⋅v  (0) - 13206400⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2  2                                12
# SigmaVecdotv⋅ν ⋅v (0) + 120492⋅Gm⋅SigmaVecdotv⋅ν⋅v  (0) - 21420800⋅Gm⋅SigmaVec
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2                             12                               2
# dotv⋅ν⋅v (0) - 36378⋅Gm⋅SigmaVecdotv⋅v  (0) + 6467200⋅Gm⋅SigmaVecdotv⋅v (0) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2              6                 2                  6
# 250560⋅Gm⋅c ⋅δ⋅nHatdotS⃗⋅v (0) - 267840⋅Gm⋅c ⋅nHatdotSigma⃗⋅ν⋅v (0) + 69120⋅Gm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                6                                    2    6
# ⋅c ⋅nHatdotSigma⃗⋅v (0) - 597600⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv ⋅ν⋅v (0) - 16560⋅Gm⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2  6                                       12
# ⋅nHatdotS⃗⋅nHatdotv ⋅v (0) + 62622⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅ν⋅v  (0) - 11132800
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             2                                     12
# ⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅ν⋅v (0) + 22824⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅v  (0) - 4057
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                              2                                8
# 600⋅Gm⋅δ⋅nHatdotS⃗⋅nHatdotv⋅v (0) - 1747200⋅Gm⋅δ⋅nHatdotS⃗⋅ν⋅v (0) + 576240⋅Gm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               8                                       2  2  6
# ⋅δ⋅nHatdotS⃗⋅v (0) + 1545840⋅Gm⋅nHatdotSigma⃗⋅nHatdotv ⋅ν ⋅v (0) - 409680⋅Gm⋅n
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                      2    6                                    2  6
# HatdotSigma⃗⋅nHatdotv ⋅ν⋅v (0) + 9360⋅Gm⋅nHatdotSigma⃗⋅nHatdotv ⋅v (0) - 77256
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             2  12                                          2
# ⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅ν ⋅v  (0) + 13734400⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅ν ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                                         12
#  (0) - 43002⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅ν⋅v  (0) + 7644800⋅Gm⋅nHatdotSigma⃗⋅nHa
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          2                                       12
# tdotv⋅ν⋅v (0) + 12456⋅Gm⋅nHatdotSigma⃗⋅nHatdotv⋅v  (0) - 2214400⋅Gm⋅nHatdotSig
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2                                2  8
# ma⃗⋅nHatdotv⋅v (0) + 1530480⋅Gm⋅nHatdotSigma⃗⋅ν ⋅v (0) + 2289840⋅Gm⋅nHatdotSig
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        8                               8                     2    10
# ma⃗⋅ν⋅v (0) - 744240⋅Gm⋅nHatdotSigma⃗⋅v (0) + 8316⋅SVecdotv⋅c ⋅δ⋅v  (0) + 1900
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2                                  6
# 800⋅SVecdotv⋅c ⋅δ - 14400⋅SVecdotv⋅δ⋅nHatdotv⋅ν⋅v (0) + 7200⋅SVecdotv⋅δ⋅nHatdo
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     6                          12                            2
# tv⋅v (0) + 30564⋅SVecdotv⋅δ⋅ν⋅v  (0) - 5433600⋅SVecdotv⋅δ⋅ν⋅v (0) - 7263⋅SVecd
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        12                          2                          2    10
# otv⋅δ⋅v  (0) + 1291200⋅SVecdotv⋅δ⋅v (0) - 39060⋅SigmaVecdotv⋅c ⋅ν⋅v  (0) - 892
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2                        2  10                            2
# 8000⋅SigmaVecdotv⋅c ⋅ν + 8316⋅SigmaVecdotv⋅c ⋅v  (0) + 1900800⋅SigmaVecdotv⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                  2  6                                     6
#  + 100800⋅SigmaVecdotv⋅nHatdotv⋅ν ⋅v (0) - 57600⋅SigmaVecdotv⋅nHatdotv⋅ν⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                6                           2  12
#  + 7200⋅SigmaVecdotv⋅nHatdotv⋅v (0) - 162027⋅SigmaVecdotv⋅ν ⋅v  (0) + 28804800
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                2  2                            12
# ⋅SigmaVecdotv⋅ν ⋅v (0) + 69849⋅SigmaVecdotv⋅ν⋅v  (0) - 12417600⋅SigmaVecdotv⋅ν
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                         12                            2             2
# ⋅v (0) - 7263⋅SigmaVecdotv⋅v  (0) + 1291200⋅SigmaVecdotv⋅v (0) - 95040⋅c ⋅δ⋅nH
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          6              2                  6             2                6
# atdotS⃗⋅v (0) + 406080⋅c ⋅nHatdotSigma⃗⋅ν⋅v (0) - 95040⋅c ⋅nHatdotSigma⃗⋅v (0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          8                          8
#  + 608160⋅δ⋅nHatdotS⃗⋅ν⋅v (0) - 137760⋅δ⋅nHatdotS⃗⋅v (0) - 2976960⋅nHatdotSigm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2  8                               8                            8   ⎞
# a⃗⋅ν ⋅v (0) + 1293600⋅nHatdotSigma⃗⋅ν⋅v (0) - 137760⋅nHatdotSigma⃗⋅v (0)⎠⋅v(0)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ⎞  4
# ⎠⋅v (0)
# ───────

# %%
tmp = simplify( sphericalharmonictensors.Vlm(V_L,2)

# %%
lazy_series = tmp.lseries(v0, 0)
[lazy_series.next().simplify() for i_term in range(3)]
# Out:
# ⎡    ____   ___     4                    ____   ___     6
# ⎢4⋅╲╱ 10 ⋅╲╱ π ⋅ν⋅v₀ ⋅(ⅈ⋅Σ_λ - Σ_n)  2⋅╲╱ 10 ⋅╲╱ π ⋅ν⋅v₀ ⋅(-40⋅ⅈ⋅Gm⋅S_λ⋅δ - 19
# ⎢──────────────────────────────────, ─────────────────────────────────────────
# ⎢               5⋅c
# ⎣
#
#
# 2⋅Gm⋅S_n⋅δ + 71⋅ⅈ⋅Gm⋅Σ_λ⋅ν - 61⋅ⅈ⋅Gm⋅Σ_λ + 177⋅Gm⋅Σ_n⋅ν - 3⋅Gm⋅Σ_n - 124⋅ⅈ⋅S_λ
# ──────────────────────────────────────────────────────────────────────────────
#                                                    3
#                                               105⋅c
#
#                                                                  ____   ___
# ⋅δ + 80⋅S_n⋅δ + 477⋅ⅈ⋅Σ_λ⋅ν - 103⋅ⅈ⋅Σ_λ - 233⋅Σ_n⋅ν + 59⋅Σ_n)  ╲╱ 10 ⋅╲╱ π ⋅ν⋅
# ─────────────────────────────────────────────────────────────, ───────────────
#
#
#
#   8 ⎛       2        2             2        2         2        2            2
# v₀ ⋅⎝400⋅ⅈ⋅G ⋅S_λ⋅δ⋅m ⋅ν + 1648⋅ⅈ⋅G ⋅S_λ⋅δ⋅m  - 1584⋅G ⋅S_n⋅δ⋅m ⋅ν + 11376⋅G ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2           2      2  2           2      2            2      2
# S_n⋅δ⋅m  - 3142⋅ⅈ⋅G ⋅Σ_λ⋅m ⋅ν  - 7790⋅ⅈ⋅G ⋅Σ_λ⋅m ⋅ν + 550⋅ⅈ⋅G ⋅Σ_λ⋅m  - 10890⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2      2  2          2      2           2      2
# G ⋅Σ_n⋅m ⋅ν  - 12114⋅G ⋅Σ_n⋅m ⋅ν + 4410⋅G ⋅Σ_n⋅m  - 10680⋅ⅈ⋅Gm⋅S_λ⋅δ⋅ν - 2040⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                 2
# ⅈ⋅Gm⋅S_λ⋅δ + 22448⋅Gm⋅S_n⋅δ⋅ν - 6232⋅Gm⋅S_n⋅δ + 26007⋅ⅈ⋅Gm⋅Σ_λ⋅ν  + 35139⋅ⅈ⋅Gm
# ──────────────────────────────────────────────────────────────────────────────
#                            5
#                      1890⋅c
#
#                                         2
# ⋅Σ_λ⋅ν - 12993⋅ⅈ⋅Gm⋅Σ_λ - 14855⋅Gm⋅Σ_n⋅ν  - 14299⋅Gm⋅Σ_n⋅ν + 7457⋅Gm⋅Σ_n + 127
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                        2
# 68⋅ⅈ⋅S_λ⋅δ⋅ν - 3036⋅ⅈ⋅S_λ⋅δ - 7872⋅S_n⋅δ⋅ν + 1776⋅S_n⋅δ - 55113⋅ⅈ⋅Σ_λ⋅ν  + 237
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                      2                         ⎞⎤
# 39⋅ⅈ⋅Σ_λ⋅ν - 2469⋅ⅈ⋅Σ_λ + 25629⋅Σ_n⋅ν  - 11175⋅Σ_n⋅ν + 1209⋅Σ_n⎠⎥
# ────────────────────────────────────────────────────────────────⎥
#                                                                 ⎥
#                                                                 ⎦

# %%
simplify(_38[1].subs({'nHatdotv':0}).subs({'SVecdotv':v0*S_lambda,
                                  'SigmaVecdotv':v0*Sigma_lambda,}))
# Out:
#      ____     ___     6
# -8⋅╲╱ 10 ⋅ⅈ⋅╲╱ π ⋅ν⋅v₀ ⋅(33⋅S_λ⋅δ - 155⋅Σ_λ⋅ν + 33⋅Σ_λ)
# ────────────────────────────────────────────────────────
#                               3
#                          105⋅c

# %%
simplify(_38[2].subs({'nHatdotv':0}).subs({'SVecdotv':v0*S_lambda, 'SigmaVecdotv':v0*Sigma_lambda,
                                           'nHatdotSVec':S_n, 'nHatdotSigmaVec':Sigma_n, }))
# Out:
#      ____   ___     6
# -2⋅╲╱ 10 ⋅╲╱ π ⋅ν⋅v₀ ⋅(40⋅ⅈ⋅Gm⋅S_λ⋅δ + 192⋅Gm⋅S_n⋅δ - 71⋅ⅈ⋅Gm⋅Σ_λ⋅ν + 61⋅ⅈ⋅Gm⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# Σ_λ - 177⋅Gm⋅Σ_n⋅ν + 3⋅Gm⋅Σ_n - 8⋅ⅈ⋅S_λ⋅δ - 80⋅S_n⋅δ + 143⋅ⅈ⋅Σ_λ⋅ν - 29⋅ⅈ⋅Σ_λ
# ──────────────────────────────────────────────────────────────────────────────
#              3
#         105⋅c
#
#
# + 233⋅Σ_n⋅ν - 59⋅Σ_n)
# ──────────────────────
